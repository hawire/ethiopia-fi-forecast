# %% [markdown]
# # Event Impact Modeling
# This notebook builds an event→indicator association matrix from `impact_link` records and validates model estimates against historical changes (Telebirr, M-Pesa).

# %%
from src.models.event_impact import main
main()

# %%
import pandas as pd
from pathlib import Path
OUT = Path('..') / 'reports'
matrix = pd.read_csv(OUT / 'event_indicator_matrix.csv', index_col=0)
matrix

# %%
from PIL import Image
from IPython.display import display
display(Image.open('../reports/figures/event_indicator_matrix.png'))

# %% [markdown]
# ## Validation check (Telebirr)
# We compare modeled effect (from matrix) to observed change in mobile money/digital payment indicators between 2021 and 2024. Document any mismatches and likely reasons.
