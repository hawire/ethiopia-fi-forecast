# %% [markdown]
# # Modeling & Forecasting
#
# This notebook runs a simple regression-based forecast for Account Ownership (Access) for 2025-2027 using mobile subscribers and 4G coverage as predictors.

# %%
from src.models.forecast import main

main()
